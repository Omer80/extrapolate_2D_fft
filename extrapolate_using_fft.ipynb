# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %%
data = np.load("field_lx_14_864408108.npz")
X,Y,field=data['X'],data['Y'],data['field']
print(field.shape)
plt.pcolormesh(X,Y,field)
# Out:
# (74, 128)

# %%
field_fft=np.fft.rfft2(field)
print(field_fft.shape)
# Out:
# (74, 65)
